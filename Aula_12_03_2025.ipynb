# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("C:/Users/20231ENPRO0038/GG_PYHON/questionario.csv", sep=';', decimal=",")

df

# Visulizar apenas as primeiras visualizações

df.head(10)

sns.boxplot(df['Alt'])
plt.title("Bloxplot a")



#Tabulação Cruzada

tabela_sexo_turma = pd.crosstab(df['Sexo'], df['Turma'])
tabela_sexo_turma

grafico = tabela_sexo_turma.plot.bar(color = ['tomato', 'lightseagreen'])
grafico.set_xticklabels(['F','M'], rotation = 0)

#Tabulação Cruzada
grafico = tabela_sexo_turma.plot.bar(stacked = True ,color = ['tomato', 'lightseagreen'])

# %% [markdown]
# # Uma variável qualitativa e outra quantitativa.

# %%
# Medidas descritivas por grupo
# Média por grupo.

df.groupby(['Sexo'])['Alt'].mean()
# Out:
# Sexo
# F    1.633784
# M    1.780769
# Name: Alt, dtype: float64

# %%
sns.boxplot(x = "Sexo", y = "Alt", data = df)
# Out:
# <Axes: xlabel='Sexo', ylabel='Alt'>

# %% [markdown]
# # Duas variáves quantitativas

# %%
sns.scatterplot(x="Alt", y = "Peso", data = df)
# Out:
# <Axes: xlabel='Alt', ylabel='Peso'>

# %%
#Criando nova coluna com base em outros que já exixte
df['INC'] = df['Peso'] / df['Alt']**2
df
# Out:
#     Id Turma Sexo  Idade   Alt  Peso  Filhos Fuma Toler  Exerc  Cine OpCine  \
# 0    1     A    F     17  1.60  60.5       2  NAO     P      0     1      B
# 1    2     A    F     18  1.69  55.0       1  NAO     M      0     1      B
# 2    3     A    M     18  1.85  72.8       2  NAO     P      5     2      M
# 3    4     A    M     25  1.85  80.9       2  NAO     P      5     2      B
# 4    5     A    F     19  1.58  55.0       1  NAO     M      2     2      B
# 5    6     A    M     19  1.76  60.0       3  NAO     M      2     1      B
# 6    7     A    F     20  1.60  58.0       1  NAO     P      3     1      B
# 7    8     A    F     18  1.64  47.0       1  SIM     I      2     2      M
# 8    9     A    F     18  1.62  57.8       3  NAO     M      3     3      M
# 9   10     A    F     17  1.64  58.0       2  NAO     M      2     2      M
# 10  11     A    F     18  1.72  70.0       1  SIM     I     10     2      B
# ...

# %%
#Criando coluna com base em uma condição


df['Alto'] = ['Pessoa alta' if x > 1.7 else 'Pessoa baixa' for x in df['Alt']]
                                                                      
df
# Out:
#     Id Turma Sexo  Idade   Alt  Peso  Filhos Fuma Toler  Exerc  Cine OpCine  \
# 0    1     A    F     17  1.60  60.5       2  NAO     P      0     1      B
# 1    2     A    F     18  1.69  55.0       1  NAO     M      0     1      B
# 2    3     A    M     18  1.85  72.8       2  NAO     P      5     2      M
# 3    4     A    M     25  1.85  80.9       2  NAO     P      5     2      B
# 4    5     A    F     19  1.58  55.0       1  NAO     M      2     2      B
# 5    6     A    M     19  1.76  60.0       3  NAO     M      2     1      B
# 6    7     A    F     20  1.60  58.0       1  NAO     P      3     1      B
# 7    8     A    F     18  1.64  47.0       1  SIM     I      2     2      M
# 8    9     A    F     18  1.62  57.8       3  NAO     M      3     3      M
# 9   10     A    F     17  1.64  58.0       2  NAO     M      2     2      M
# 10  11     A    F     18  1.72  70.0       1  SIM     I     10     2      B
# ...
